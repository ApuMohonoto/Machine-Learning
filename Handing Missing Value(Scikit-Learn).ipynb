# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
data=pd.read_csv(r"R:\CSV Files\Loan_Default.csv")
data.head(10)
# Out:
#       ID  year loan_limit             Gender approv_in_adv loan_type  \
# 0  24890  2019         cf  Sex Not Available         nopre     type1
# 1  24891  2019         cf               Male         nopre     type2
# 2  24892  2019         cf               Male           pre     type1
# 3  24893  2019         cf               Male         nopre     type1
# 4  24894  2019         cf              Joint           pre     type1
# 5  24895  2019         cf              Joint           pre     type1
# 6  24896  2019         cf              Joint           pre     type1
# 7  24897  2019        NaN             Female         nopre     type1
# 8  24898  2019         cf              Joint         nopre     type1
# 9  24899  2019         cf  Sex Not Available         nopre     type3
#
#   loan_purpose Credit_Worthiness open_credit business_or_commercial  ...  \
# 0           p1                l1        nopc                  nob/c  ...
# ...

# %%
data.isnull().sum()
# Out:
# ID                               0
# year                             0
# loan_limit                    3344
# Gender                           0
# approv_in_adv                  908
# loan_type                        0
# loan_purpose                   134
# Credit_Worthiness                0
# open_credit                      0
# business_or_commercial           0
# loan_amount                      0
# rate_of_interest             36439
# Interest_rate_spread         36639
# Upfront_charges              39642
# term                            41
# Neg_ammortization              121
# interest_only                    0
# lump_sum_payment                 0
# property_value               15098
# construction_type                0
# occupancy_type                   0
# Secured_by                       0
# total_units                      0
# income                        9150
# credit_type                      0
# Credit_Score                     0
# co-applicant_credit_type         0
# ...

# %%
from sklearn.impute import SimpleImputer
s=SimpleImputer(strategy="mean")
ar=s.fit_transform(data[['rate_of_interest', 'Interest_rate_spread', 'Upfront_charges', 'term',
       'property_value', 'income', 'LTV', 'dtir1']])
 
new=pd.DataFrame(ar,columns=data.select_dtypes(include="float64").columns)

# %%
new.isnull().sum()
# Out:
# rate_of_interest        0
# Interest_rate_spread    0
# Upfront_charges         0
# term                    0
# property_value          0
# income                  0
# LTV                     0
# dtir1                   0
# dtype: int64

# %%
data.select_dtypes(include="float64").columns
# Out:
# Index(['rate_of_interest', 'Interest_rate_spread', 'Upfront_charges', 'term',
#        'property_value', 'income', 'LTV', 'dtir1'],
#       dtype='object')

# %%
new.head(10)
# Out:
#    rate_of_interest  Interest_rate_spread  Upfront_charges   term  \
# 0          4.045476              0.441656      3224.996127  360.0
# 1          4.045476              0.441656      3224.996127  360.0
# 2          4.560000              0.200000       595.000000  360.0
# 3          4.250000              0.681000      3224.996127  360.0
# 4          4.000000              0.304200         0.000000  360.0
# 5          3.990000              0.152300       370.000000  360.0
# 6          4.500000              0.999800      5120.000000  360.0
# 7          4.125000              0.297500      5609.880000  360.0
# 8          4.875000              0.739500      1150.000000  360.0
# 9          3.490000             -0.277600      2316.500000  360.0
#
#    property_value   income        LTV      dtir1
# 0    1.180000e+05   1740.0  98.728814  45.000000
# 1    4.978935e+05   4980.0  72.746457  37.732932
# 2    5.080000e+05   9480.0  80.019685  46.000000
# ...

# %%
new
# Out:
#         rate_of_interest  Interest_rate_spread  Upfront_charges   term  \
# 0               4.045476              0.441656      3224.996127  360.0
# 1               4.045476              0.441656      3224.996127  360.0
# 2               4.560000              0.200000       595.000000  360.0
# 3               4.250000              0.681000      3224.996127  360.0
# 4               4.000000              0.304200         0.000000  360.0
# ...                  ...                   ...              ...    ...
# 148665          3.125000              0.257100      9960.000000  180.0
# 148666          5.190000              0.854400         0.000000  360.0
# 148667          3.125000              0.081600      1226.640000  180.0
# 148668          3.500000              0.582400      4323.330000  180.0
# 148669          4.375000              1.387100      6000.000000  240.0
#
#         property_value   income        LTV      dtir1
# 0        118000.000000   1740.0  98.728814  45.000000
# ...
