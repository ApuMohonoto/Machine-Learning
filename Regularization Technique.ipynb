# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
data=pd.read_csv(r"R:\CSV Files\Iris - all-numbers1.csv")
data.head(3)
# Out:
#    3.5  1.4  0.2  0  5.1
# 0  3.0  1.4  0.2  0  4.9
# 1  3.2  1.3  0.2  0  4.7
# 2  3.1  1.5  0.2  0  4.6

# %%
data.isnull().sum()
# Out:
# 3.5    0
# 1.4    0
# 0.2    0
# 0      0
# 5.1    0
# dtype: int64

# %%
sns.heatmap(data=data.corr(),annot=True)# determine the linearity, here annot determine the correlation number
plt.show()

# %%
x=data.iloc[:,:-1]
y=data["5.1"]

# %%
sc=StandardScaler()
sc.fit(x)
x=pd.DataFrame(sc.transform(x),columns=x.columns)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.2,random_state=42)

# %% [markdown]
# # Linear Regression

# %%
sc=StandardScaler()
lr=LinearRegression()
lr.fit(x_train,y_train)
lr.score(x_test,y_test)*100
# Out:
# 84.9377671234484

# %%
lr.coef_
# Out:
# array([ 0.27473648,  1.37385422, -0.3603494 , -0.21973656])

# %%
plt.figure(figsize=(15,10))
plt.bar(x.columns,lr.coef_)
plt.title("LinearRegression")
plt.xlabel("Columns")
plt.ylabel("Coef")
plt.show()

# %% [markdown]
# # Lasso

# %%
la=Lasso(alpha=.09)
la.fit(x_train,y_train)
la.score(x_test,y_test)*100
# Out:
# 82.49736284423348

# %%
plt.figure(figsize=(15,10))
plt.bar(x.columns,la.coef_)
plt.title("LinearRegression")
plt.xlabel("Columns")
plt.ylabel("Coef")
plt.show()

# %% [markdown]
# # Ridge

# %%
r=Ridge(alpha=10)
r.fit(x_train,y_train)
r.score(x_test,y_test)*100
# Out:
# 84.9404446922331

# %%
plt.figure(figsize=(15,10))
plt.bar(x.columns,r.coef_)
plt.title("LinearRegression")
plt.xlabel("Columns")
plt.ylabel("Coef")
plt.show()
